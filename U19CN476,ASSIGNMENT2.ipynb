# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("NBA_data.csv")

# %%
df
# Out:
#                 Player Position  Age  Games  Minutes Played  True Shooting(%)  \
# 0     Precious Achiuwa       PF   21     28           408.0             0.599
# 1         Jaylen Adams       PG   24      6            17.0             0.125
# 2         Steven Adams        C   27     27           760.0             0.592
# 3          Bam Adebayo        C   23     26           873.0             0.641
# 4    LaMarcus Aldridge        C   35     18           480.0             0.542
# ..                 ...      ...  ...    ...             ...               ...
# 492       Delon Wright       SG   28     28           823.0             0.559
# 493     Thaddeus Young       PF   32     23           592.0             0.597
# 494         Trae Young       PG   22     26           901.0             0.598
# 495        Cody Zeller        C   28     15           361.0             0.569
# 496        Ivica Zubac        C   23     30           586.0             0.722
#
# ...

# %%
df.isnull().sum()
# Out:
# Player                      0
# Position                    0
# Age                         0
# Games                       0
# Minutes Played              2
# True Shooting(%)            3
# Threepoint Attempt rate     2
# Free throw attempt rate     2
# Player Efficiency Rating    0
# dtype: int64

# %%
missing_value = ["na",np.nan]
df = pd.read_csv("NBA_data.csv",na_values=missing_value)

# %%
df.isnull().sum()
# Out:
# Player                      0
# Position                    0
# Age                         0
# Games                       0
# Minutes Played              2
# True Shooting(%)            3
# Threepoint Attempt rate     2
# Free throw attempt rate     2
# Player Efficiency Rating    0
# dtype: int64

# %%
df.isnull().any()
# Out:
# Player                      False
# Position                    False
# Age                         False
# Games                       False
# Minutes Played               True
# True Shooting(%)             True
# Threepoint Attempt rate      True
# Free throw attempt rate      True
# Player Efficiency Rating    False
# dtype: bool

# %%
sns.heatmap(df.isnull(), yticklabels=False)
# Out:
# <AxesSubplot:>

# %%
df.dropna()
# Out:
#                 Player Position  Age  Games  Minutes Played  True Shooting(%)  \
# 0     Precious Achiuwa       PF   21     28           408.0             0.599
# 1         Jaylen Adams       PG   24      6            17.0             0.125
# 3          Bam Adebayo        C   23     26           873.0             0.641
# 4    LaMarcus Aldridge        C   35     18           480.0             0.542
# 5    Ty-Shon Alexander       SG   22      3             8.0             0.000
# ..                 ...      ...  ...    ...             ...               ...
# 492       Delon Wright       SG   28     28           823.0             0.559
# 493     Thaddeus Young       PF   32     23           592.0             0.597
# 494         Trae Young       PG   22     26           901.0             0.598
# 495        Cody Zeller        C   28     15           361.0             0.569
# 496        Ivica Zubac        C   23     30           586.0             0.722
#
# ...

# %%
df_dropped = df.interpolate()

# %%
df_dropped
# Out:
#                 Player Position  Age  Games  Minutes Played  True Shooting(%)  \
# 0     Precious Achiuwa       PF   21     28           408.0             0.599
# 1         Jaylen Adams       PG   24      6            17.0             0.125
# 2         Steven Adams        C   27     27           760.0             0.592
# 3          Bam Adebayo        C   23     26           873.0             0.641
# 4    LaMarcus Aldridge        C   35     18           480.0             0.542
# ..                 ...      ...  ...    ...             ...               ...
# 492       Delon Wright       SG   28     28           823.0             0.559
# 493     Thaddeus Young       PF   32     23           592.0             0.597
# 494         Trae Young       PG   22     26           901.0             0.598
# 495        Cody Zeller        C   28     15           361.0             0.569
# 496        Ivica Zubac        C   23     30           586.0             0.722
#
# ...

# %%
sns.barplot(df['Player'], df['Age'])
# Out:
# C:\Users\Imran basha\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Player', ylabel='Age'>

# %%
sns.pairplot(df[['Player', 'Age', 'Games','Minutes Played', 'Player Efficiency Rating', 'True Shooting(%)','Threepoint Attempt rate','Free throw attempt rate']])

# %%
sns.countplot(df['Games'])
# Out:
# C:\Users\Imran basha\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Games', ylabel='count'>

# %%
sns.pointplot(df['Player'], df['Age'])
# Out:
# C:\Users\Imran basha\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Player', ylabel='Age'>

# %%
x = df.iloc[:,:-1].values
print(x)
# Out:
# [['Precious Achiuwa' 'PF' 21 ... 0.599 0.0 0.541]
#  ['Jaylen Adams' 'PG' 24 ... 0.125 0.25 0.0]
#  ['Steven Adams' 'C' 27 ... 0.592 nan 0.397]
#  ...
#  ['Trae Young' 'PG' 22 ... 0.598 0.349 0.577]
#  ['Cody Zeller' 'C' 28 ... 0.569 0.133 0.242]
#  ['Ivica Zubac' 'C' 23 ... 0.722 0.007 0.5]]

# %%
y = df.iloc[:,-1].values
print(y)
# Out:
# [ 15.1  -6.9  15.9  22.7  15.2 -11.9  12.   14.   22.5  21.3  23.5   7.5
#   17.8  28.3  -9.1  10.3  13.8  10.3  14.7  11.2  10.8   8.9  17.7  10.6
#   10.7  13.9  18.2  14.2  23.4  12.6  15.7  13.1  11.6   0.3  14.8   8.4
#   14.7   9.6  24.8  16.7   8.   13.2  11.5  13.7  13.   14.   16.1  18.3
#   12.6  12.6  12.6  -6.    9.9  12.3   4.7  13.4   9.    5.   17.2  23.4
#   17.8  10.4  20.3  10.3  11.4  16.3  12.   18.3  10.3  12.8  22.3  33.5
#   12.9   5.4  16.4  18.8   8.9  13.7  13.5  24.2   9.2  38.7   9.8  12.1
#    2.1  23.1  29.8   8.3  17.1   8.2  11.5  14.8  10.7  11.9   5.3  16.6
#   19.   10.1  19.3  19.8  13.2  12.4  15.1  10.   11.6  11.5  10.7  14.1
#   25.6  24.7  12.2  11.2  21.7  15.9  18.6  10.1  12.7  26.8   9.5   9.9
#    6.7   6.1  13.6  13.4  20.9  11.5  25.1  10.5  12.2  12.2  12.8  30.8
#   12.7  12.4   6.1  22.5  20.6  18.1  -5.9   7.4  12.7  11.    4.5  11.8
#    9.2  17.5  19.9   0.3  12.2  -1.4  17.6  12.5  13.2  12.9  10.3  13.9
# ...
